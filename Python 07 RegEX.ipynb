# %%
import re

txt = "The rain in Spain"
x = re.findall("ai", txt)

print(x)
# Out:
# ['ai', 'ai']

# %%
import re

txt = "The rain in Spain"
x = re.search("\s", txt)

print(x.start())
# Out:
# 3
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\LG\AppData\Local\Temp\ipykernel_23680\4156067783.py:4: SyntaxWarning: invalid escape sequence '\s'
#   x = re.search("\s", txt)

# %%
import re

txt = "The rain in Spain"
x = re.search("Portugal", txt)

print(x)
# Out:
# None

# %%
import re

txt = "The rain in Spain"
x = re.split("\s", txt)

print(x)
# Out:
# ['The', 'rain', 'in', 'Spain']
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\LG\AppData\Local\Temp\ipykernel_23680\1619206112.py:4: SyntaxWarning: invalid escape sequence '\s'
#   x = re.split("\s", txt)

# %%
import re

txt = "The rain in Spain"
x = re.split("\s", txt, 1)

print(x)
# Out:
# ['The', 'rain in Spain']
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\LG\AppData\Local\Temp\ipykernel_23680\2424869248.py:4: SyntaxWarning: invalid escape sequence '\s'
#   x = re.split("\s", txt, 1)

# %%
import re

txt = "The rain in Spain"
x = re.sub("\s", "9", txt)

print(x)
# Out:
# The9rain9in9Spain
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\LG\AppData\Local\Temp\ipykernel_23680\1933543340.py:4: SyntaxWarning: invalid escape sequence '\s'
#   x = re.sub("\s", "9", txt)

# %%
import re

txt = "The rain in Spain"
x = re.sub("\s", "9", txt, 2)

print(x)
# Out:
# The9rain9in Spain
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\LG\AppData\Local\Temp\ipykernel_23680\2062105906.py:4: SyntaxWarning: invalid escape sequence '\s'
#   x = re.sub("\s", "9", txt, 2)

# %%
import re

txt = "The rain in Spain"
x = re.search("ai", txt)

print(x.group())
print(x.span())
# Out:
# ai
# (5, 7)

# %%
import re

txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)

print(x.group())
# Out:
# Spain

# %%
try:
    print(x)  
except:
    print("Error 발생")
# Out:
# <re.Match object; span=(12, 17), match='Spain'>

# %%
price = 59
txt = f"The price is {price} dollars"

print(txt)
# Out:
# The price is 59 dollars

# %%
price = 49
txt = f"It is {'Expensive' if price > 50 else 'Cheap'}"

print(txt)
# Out:
# It is Cheap

# %%
def myconverter(x):
    return x * 0.3048

txt = f"{myconverter(100)}"
print(txt)
# Out:
# 30.48

# %%
result = None

if result is None:
    print("No result")
# Out:
# No result
